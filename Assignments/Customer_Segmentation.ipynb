# %% [markdown]
# <a href="https://colab.research.google.com/github/hariharankpz/Playground/blob/master/Assignments/Customer_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb516060-4dca-4ee7-881c-a25bfe791d2a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb516060-4dca-4ee7-881c-a25bfe791d2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test_Secnario2.xls to Test_Secnario2.xls

# %%
import pandas as pd
import numpy as np
# !pip install xlrd==1.2.0

# %%
df = pd.read_excel("Test_Secnario2.xls")

# %%
df.head()
# Out:
#    CUSTOMER_NUMBER GENDER    AGE NATIONALITY MARITAL_STATUS PRODUCT_CODE  \
# 0             1007      F  113.0          IN            NaN        VOYCC
# 1            10101      M   30.0          IN              M           SA
# 2            10101      M   30.0          IN              M           SA
# 3            10101      M   30.0          IN              M           SA
# 4            10101      M   30.0          IN              M           SA
#
#   PURCHASE_DATE  TRANS_NUM    POINT_TYPE  POINTS  Unnamed: 10  \
# 0    2019-08-09  ACT633528   BASE_POINTS      11          NaN
# 1    2019-04-01  ACT623150  OFFER_POINTS      23          NaN
# 2    2019-04-01  ACT623150   BASE_POINTS      26          NaN
# 3    2019-07-01  ACT628206  OFFER_POINTS      23          NaN
# 4    2019-07-01  ACT628206  BONUS_POINTS      32          NaN
#
#            Unnamed: 11                     Unnamed: 12
# 0                  NaN                             NaN
# 1                  NaN                             NaN
# 2  Dataset Description                             NaN
# 3            Attribute                     Description
# 4      CUSTOMER_NUMBER  Customer Identification Number

# %%
df.columns
# Out:
# Index(['CUSTOMER_NUMBER', 'GENDER', 'AGE', 'NATIONALITY', 'MARITAL_STATUS',
#        'PRODUCT_CODE', 'PURCHASE_DATE', 'TRANS_NUM', 'POINT_TYPE', 'POINTS',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df.drop(["Unnamed: 10", "Unnamed: 11", "Unnamed: 12"],axis=1,inplace=True)

# %%
features_with_na = [feature for feature in df.columns if df[feature].isnull().sum()>1 ]
#mean - sum of all data points/number of all datapoints
for feature in features_with_na:
    print(feature, np.round(df[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# AGE 0.1667  % missing values
# MARITAL_STATUS 0.5556  % missing values

# %%
df["AGE"].fillna(df["AGE"].mean(), inplace = True)
df["MARITAL_STATUS"].fillna("MISSING", inplace = True)

# %%
df.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False])

# %%
df.drop(["CUSTOMER_NUMBER","TRANS_NUM","PURCHASE_DATE"],axis=1,inplace=True)

df.head()
# Out:
#   GENDER    AGE NATIONALITY MARITAL_STATUS PRODUCT_CODE    POINT_TYPE  POINTS
# 0      F  113.0          IN        MISSING        VOYCC   BASE_POINTS      11
# 1      M   30.0          IN              M           SA  OFFER_POINTS      23
# 2      M   30.0          IN              M           SA   BASE_POINTS      26
# 3      M   30.0          IN              M           SA  OFFER_POINTS      23
# 4      M   30.0          IN              M           SA  BONUS_POINTS      32

# %%
from sklearn import preprocessing
customers_norm = df.copy()
scaler = preprocessing.MinMaxScaler()
customers_norm[['AGE','POINTS']] = scaler.fit_transform(customers_norm[['AGE','POINTS']])

# %%
# df.iloc[:,[0,2,3,4,5]] #categorical columns

# %%
customers_norm.head()
# Out:
#   GENDER       AGE NATIONALITY MARITAL_STATUS PRODUCT_CODE    POINT_TYPE  \
# 0      F  1.000000          IN        MISSING        VOYCC   BASE_POINTS
# 1      M  0.117021          IN              M           SA  OFFER_POINTS
# 2      M  0.117021          IN              M           SA   BASE_POINTS
# 3      M  0.117021          IN              M           SA  OFFER_POINTS
# 4      M  0.117021          IN              M           SA  BONUS_POINTS
#
#      POINTS
# 0  0.000000
# 1  0.010591
# 2  0.013239
# 3  0.010591
# 4  0.018535

# %%
# !pip install kmodes
from kmodes.kprototypes import KPrototypes
kproto = KPrototypes(n_clusters=3, init='Cao')
clusters = kproto.fit_predict(customers_norm, categorical=[0,2,3,4,5])
#join data with labels 
labels = pd.DataFrame(clusters)
labeledCustomers = pd.concat((df,labels),axis=1)
labeledCustomers = labeledCustomers.rename({0:'labels'},axis=1)

# %%
labeledCustomers.head(100)
# Out:
#    GENDER         AGE NATIONALITY MARITAL_STATUS PRODUCT_CODE  \
# 0       F  113.000000          IN        MISSING        VOYCC
# 1       M   30.000000          IN              M           SA
# 2       M   30.000000          IN              M           SA
# 3       M   30.000000          IN              M           SA
# 4       M   30.000000          IN              M           SA
# 5       M   30.000000          IN              M           SA
# 6       M   30.000000          IN              M           SA
# 7       M   19.000000          AF        MISSING           SA
# 8       M   19.000000          AF        MISSING           SA
# 9       M   19.000000          AF        MISSING           SA
# 10      M   19.000000          AF        MISSING           SA
# 11      M   19.000000          AF        MISSING          HNC
# 12      M   19.000000          AF        MISSING           SA
# 13      M   22.000000          IN        MISSING           SA
# 14      M   22.000000          IN        MISSING           SA
# 15      M   30.066667          IN        MISSING           BD
# 16      M   30.066667          IN              D           SA
# 17      M   30.066667          IN              D           SA
# 18      F  113.000000          IN        MISSING        VOYCC
# 19      M   30.000000          IN              M           SA
# 20      M   30.000000          IN              M           SA
# 21      M   30.000000          IN              M           SA
# 22      M   30.000000          IN              M           SA
# 23      M   30.000000          IN              M           SA
# 24      M   30.000000          IN              M           SA
# 25      M   19.000000          AF        MISSING           SA
# 26      M   19.000000          AF        MISSING           SA
# 27      M   19.000000          AF        MISSING           SA
# 28      M   19.000000          AF        MISSING           SA
# 29      M   19.000000          AF        MISSING          HNC
# 30      M   19.000000          AF        MISSING           SA
# 31      M   22.000000          IN        MISSING           SA
# 32      M   22.000000          IN        MISSING           SA
# 33      M   30.066667          IN        MISSING           BD
# 34      M   30.066667          IN              D           SA
# 35      M   30.066667          IN              D           SA
#
#           POINT_TYPE  POINTS  labels
# 0        BASE_POINTS      11       0
# 1       OFFER_POINTS      23       0
# 2        BASE_POINTS      26       0
# 3       OFFER_POINTS      23       0
# 4       BONUS_POINTS      32       0
# 5   LIFEMILES_POINTS      12       0
# 6        BASE_POINTS     112       0
# 7       OFFER_POINTS      34       2
# 8       OFFER_POINTS     112       2
# 9        BASE_POINTS      43       2
# 10  LIFEMILES_POINTS     100       2
# 11       BASE_POINTS    1144       1
# 12       BASE_POINTS     100       2
# 13       BASE_POINTS     101       2
# 14      BONUS_POINTS      32       2
# 15      BONUS_POINTS     123       0
# 16       BASE_POINTS     100       0
# 17  LIFEMILES_POINTS     100       0
# 18       BASE_POINTS      11       0
# 19      OFFER_POINTS      23       0
# 20       BASE_POINTS      26       0
# 21      OFFER_POINTS      23       0
# 22      BONUS_POINTS      32       0
# 23  LIFEMILES_POINTS      12       0
# 24       BASE_POINTS     112       0
# 25      OFFER_POINTS      34       2
# 26      OFFER_POINTS     112       2
# 27       BASE_POINTS      43       2
# 28  LIFEMILES_POINTS     100       2
# 29       BASE_POINTS    1144       1
# 30       BASE_POINTS     100       2
# 31       BASE_POINTS     101       2
# 32      BONUS_POINTS      32       2
# 33      BONUS_POINTS     123       0
# 34       BASE_POINTS     100       0
# 35  LIFEMILES_POINTS     100       0
